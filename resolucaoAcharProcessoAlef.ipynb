# %%
import nltk
import pandas as pd
import re

# %%
#le o arquivo do.txt para o python
dfDo = pd.read_fwf('D:\Python\do.txt',header=None,encoding='utf_8')
dfDo
# Out:
#                                                      0
# 0    Processo 0001040-18.2017.8.26.0100 (processo p...
# 1    55.2011.8.26.0100) - Cumprimento de sentença -...
# 2    Unit Assessoria Tecnica Ltda - Athenee Comérci...
# 3                  portação Ltda - Ciência da pesquisa
# 4                             de ativos financeiros em
# 5    nome da parte executada realizada através do s...
# 6    a qual restou parcialmente frutífera, tendo si...
# 7    valor de R$ 332,25 de acordo com o extrato ret...
# 8    DE TARSO DUTRA DE ALENCAR E SILVA (OAB 132316RJ),
# 9    SAULO  DE  TARSO  DUTRA  DE  ALENCAR  E  SILVA...
# 10                O  NAJJAR  ABRAMO  (OAB  211122/SP),
# 11      MARCELO APARECIDO BATISTA SEBA (OAB 208574/SP)
# 12   Processo  0026982-52.2017.8.26.0100  (processo...
# 13   29.2016.8.26.0100)  -  Cumprimento  Provisório...
# 14   Sentença - Defeito, nulidade ou anulação - Gus...
# 15   role - Advir Turismo Ltda - Vistos.Indefiro o ...
# 16   não esgotados os meios para localização de out...
# 17   executada, anotando-se que a execução deve se ...
# 18   da forma menos gravosa e a penhora do faturame...
# 19   abilizar a empresa executada, onerará o proces...
# 20   necessidade de nomeação de administrador-depos...
# 21   remuneração mensal. Ademais, o ordenamento jur...
# 22   ordem preferencial de penhora que deve ser obs...
# 23   disposto no artigo 835 do Código de Processo C...
# 24   se. - ADV: JOSE CARLOS D’ANDREA (OAB 22615/SP)...
# 25             RO PEDROSA VIEIRA (OAB 246744/SP), LUIS
# 26        CARLOS CIOFFI BALTRAMAVICIUS (OAB 123851/SP)
# 27   Processo  0028605-54.2017.8.26.0100  (processo...
# 28   79.2016.8.26.0100)  -  Cumprimento  de  senten...
# 29   Inclusão Indevida em Cadastro de Inadimplentes...
# ..                                                 ...
# 102  no prazo de 15 (quinze) dias, pague o valor in...
# 103  rativo discriminado e atualizado do crédito, a...
# 104                                                 s,
# 105  se houver.Fica a parte executada advertida de ...
# 106  o prazo previsto no art. 523 sem o pagamento v...
# 107                                                 a-
# 108  se o prazo de 15 (quinze) dias para que, indep...
# 109  enhora ou nova intimação, apresente, nos própr...
# 110  impugnação.Não ocorrendo pagamento voluntário ...
# 111  o 523 do CPC, o débito será acrescido de multa...
# 112  cento e, também, de honorários de advogado de ...
# 113  mais, não efetuado o pagamento voluntário no p...
# 114  (quinze) dias, independentemente de nova intim...
# 115  oderá a parte exequente efetuar pedido de pesq...
# 116  sistemas informatizados à disposição do juízo,...
# 117  r o prévio recolhimento das taxas previstas no...
# 118                                                  ,
# 119  da Lei Estadual 14.838/12, calculadas por cada...
# 120  efetuada.Por fim, certificado o trânsito em ju...
# 121                                                  e
# 122  transcorrido o prazo do art. 523, mediante o r...
# 123  espectivas taxas, a parte exequente poderá req...
# 124  à serventia a expedição de certidão, nos termo...
# 125  CPC, que servirá também aos fins previstos no ...
# 126  todos do Código de Processo Civil.Sem prejuízo...
# 127  tual processo se encontra em fase de execução,...
# 128  aos advogados, quando do cadastro de novas pet...
# 129  para fazer uso do incidente processual criado,...
# 130  do número 0047169-81.2017.8.26.0100. - ADV: RA...
# 131          RIAN (OAB 312078/SP), LUCIANA NAZIMA (OAB
#
# [132 rows x 1 columns]

# %%
#remove todos os \n (quebra de linha em unix/macOSX)
dfDo=dfDo.replace('\n','')
#remove todos os \r (quebra de linha em MacOS antes do X
dfDo=dfDo.replace('\r','')
dfDo
# Out:
#                                                      0
# 0    Processo 0001040-18.2017.8.26.0100 (processo p...
# 1    55.2011.8.26.0100) - Cumprimento de sentença -...
# 2    Unit Assessoria Tecnica Ltda - Athenee Comérci...
# 3                  portação Ltda - Ciência da pesquisa
# 4                             de ativos financeiros em
# 5    nome da parte executada realizada através do s...
# 6    a qual restou parcialmente frutífera, tendo si...
# 7    valor de R$ 332,25 de acordo com o extrato ret...
# 8    DE TARSO DUTRA DE ALENCAR E SILVA (OAB 132316RJ),
# 9    SAULO  DE  TARSO  DUTRA  DE  ALENCAR  E  SILVA...
# 10                O  NAJJAR  ABRAMO  (OAB  211122/SP),
# 11      MARCELO APARECIDO BATISTA SEBA (OAB 208574/SP)
# 12   Processo  0026982-52.2017.8.26.0100  (processo...
# 13   29.2016.8.26.0100)  -  Cumprimento  Provisório...
# 14   Sentença - Defeito, nulidade ou anulação - Gus...
# 15   role - Advir Turismo Ltda - Vistos.Indefiro o ...
# 16   não esgotados os meios para localização de out...
# 17   executada, anotando-se que a execução deve se ...
# 18   da forma menos gravosa e a penhora do faturame...
# 19   abilizar a empresa executada, onerará o proces...
# 20   necessidade de nomeação de administrador-depos...
# 21   remuneração mensal. Ademais, o ordenamento jur...
# 22   ordem preferencial de penhora que deve ser obs...
# 23   disposto no artigo 835 do Código de Processo C...
# 24   se. - ADV: JOSE CARLOS D’ANDREA (OAB 22615/SP)...
# 25             RO PEDROSA VIEIRA (OAB 246744/SP), LUIS
# 26        CARLOS CIOFFI BALTRAMAVICIUS (OAB 123851/SP)
# 27   Processo  0028605-54.2017.8.26.0100  (processo...
# 28   79.2016.8.26.0100)  -  Cumprimento  de  senten...
# 29   Inclusão Indevida em Cadastro de Inadimplentes...
# ..                                                 ...
# 102  no prazo de 15 (quinze) dias, pague o valor in...
# 103  rativo discriminado e atualizado do crédito, a...
# 104                                                 s,
# 105  se houver.Fica a parte executada advertida de ...
# 106  o prazo previsto no art. 523 sem o pagamento v...
# 107                                                 a-
# 108  se o prazo de 15 (quinze) dias para que, indep...
# 109  enhora ou nova intimação, apresente, nos própr...
# 110  impugnação.Não ocorrendo pagamento voluntário ...
# 111  o 523 do CPC, o débito será acrescido de multa...
# 112  cento e, também, de honorários de advogado de ...
# 113  mais, não efetuado o pagamento voluntário no p...
# 114  (quinze) dias, independentemente de nova intim...
# 115  oderá a parte exequente efetuar pedido de pesq...
# 116  sistemas informatizados à disposição do juízo,...
# 117  r o prévio recolhimento das taxas previstas no...
# 118                                                  ,
# 119  da Lei Estadual 14.838/12, calculadas por cada...
# 120  efetuada.Por fim, certificado o trânsito em ju...
# 121                                                  e
# 122  transcorrido o prazo do art. 523, mediante o r...
# 123  espectivas taxas, a parte exequente poderá req...
# 124  à serventia a expedição de certidão, nos termo...
# 125  CPC, que servirá também aos fins previstos no ...
# 126  todos do Código de Processo Civil.Sem prejuízo...
# 127  tual processo se encontra em fase de execução,...
# 128  aos advogados, quando do cadastro de novas pet...
# 129  para fazer uso do incidente processual criado,...
# 130  do número 0047169-81.2017.8.26.0100. - ADV: RA...
# 131          RIAN (OAB 312078/SP), LUCIANA NAZIMA (OAB
#
# [132 rows x 1 columns]

# %%
#transforma o dataframe em series
seriesDo=dfDo.iloc[:,0]
seriesDo
# Out:
# 0      Processo 0001040-18.2017.8.26.0100 (processo p...
# 1      55.2011.8.26.0100) - Cumprimento de sentença -...
# 2      Unit Assessoria Tecnica Ltda - Athenee Comérci...
# 3                    portação Ltda - Ciência da pesquisa
# 4                               de ativos financeiros em
# 5      nome da parte executada realizada através do s...
# 6      a qual restou parcialmente frutífera, tendo si...
# 7      valor de R$ 332,25 de acordo com o extrato ret...
# 8      DE TARSO DUTRA DE ALENCAR E SILVA (OAB 132316RJ),
# 9      SAULO  DE  TARSO  DUTRA  DE  ALENCAR  E  SILVA...
# 10                  O  NAJJAR  ABRAMO  (OAB  211122/SP),
# 11        MARCELO APARECIDO BATISTA SEBA (OAB 208574/SP)
# 12     Processo  0026982-52.2017.8.26.0100  (processo...
# 13     29.2016.8.26.0100)  -  Cumprimento  Provisório...
# 14     Sentença - Defeito, nulidade ou anulação - Gus...
# 15     role - Advir Turismo Ltda - Vistos.Indefiro o ...
# 16     não esgotados os meios para localização de out...
# 17     executada, anotando-se que a execução deve se ...
# 18     da forma menos gravosa e a penhora do faturame...
# 19     abilizar a empresa executada, onerará o proces...
# 20     necessidade de nomeação de administrador-depos...
# 21     remuneração mensal. Ademais, o ordenamento jur...
# 22     ordem preferencial de penhora que deve ser obs...
# 23     disposto no artigo 835 do Código de Processo C...
# 24     se. - ADV: JOSE CARLOS D’ANDREA (OAB 22615/SP)...
# 25               RO PEDROSA VIEIRA (OAB 246744/SP), LUIS
# 26          CARLOS CIOFFI BALTRAMAVICIUS (OAB 123851/SP)
# 27     Processo  0028605-54.2017.8.26.0100  (processo...
# 28     79.2016.8.26.0100)  -  Cumprimento  de  senten...
# 29     Inclusão Indevida em Cadastro de Inadimplentes...
#                              ...
# 102    no prazo de 15 (quinze) dias, pague o valor in...
# 103    rativo discriminado e atualizado do crédito, a...
# 104                                                   s,
# 105    se houver.Fica a parte executada advertida de ...
# 106    o prazo previsto no art. 523 sem o pagamento v...
# 107                                                   a-
# 108    se o prazo de 15 (quinze) dias para que, indep...
# 109    enhora ou nova intimação, apresente, nos própr...
# 110    impugnação.Não ocorrendo pagamento voluntário ...
# 111    o 523 do CPC, o débito será acrescido de multa...
# 112    cento e, também, de honorários de advogado de ...
# 113    mais, não efetuado o pagamento voluntário no p...
# 114    (quinze) dias, independentemente de nova intim...
# 115    oderá a parte exequente efetuar pedido de pesq...
# 116    sistemas informatizados à disposição do juízo,...
# 117    r o prévio recolhimento das taxas previstas no...
# 118                                                    ,
# 119    da Lei Estadual 14.838/12, calculadas por cada...
# 120    efetuada.Por fim, certificado o trânsito em ju...
# 121                                                    e
# 122    transcorrido o prazo do art. 523, mediante o r...
# 123    espectivas taxas, a parte exequente poderá req...
# 124    à serventia a expedição de certidão, nos termo...
# 125    CPC, que servirá também aos fins previstos no ...
# 126    todos do Código de Processo Civil.Sem prejuízo...
# 127    tual processo se encontra em fase de execução,...
# 128    aos advogados, quando do cadastro de novas pet...
# 129    para fazer uso do incidente processual criado,...
# 130    do número 0047169-81.2017.8.26.0100. - ADV: RA...
# 131            RIAN (OAB 312078/SP), LUCIANA NAZIMA (OAB
# Name: 0, Length: 132, dtype: object

# %%
#transforma a series em uma unica string de texto
texto=seriesDo.str.cat()
texto
# Out:
# 'Processo 0001040-18.2017.8.26.0100 (processo principal 0155113-55.2011.8.26.0100) - Cumprimento de sentença - AvalonUnit Assessoria Tecnica Ltda - Athenee Comércio Importação e Exportação Ltda - Ciência da pesquisade ativos financeiros emnome da parte executada realizada através do sistema Bacenjud,a qual restou parcialmente frutífera, tendo sido bloqueado ovalor de R$ 332,25 de acordo com o extrato retro. - ADV: SAULODE TARSO DUTRA DE ALENCAR E SILVA (OAB 132316RJ),SAULO  DE  TARSO  DUTRA  DE  ALENCAR  E  SILVA  (OAB  132316/RJ),  MARCELO  NAJJAR  ABRAMO  (OAB  211122/SP),MARCELO APARECIDO BATISTA SEBA (OAB 208574/SP)Processo  0026982-52.2017.8.26.0100  (processo  principal  1021197-29.2016.8.26.0100)  -  Cumprimento  Provisório  deSentença - Defeito, nulidade ou anulação - Gustavo Vieira Venturole - Advir Turismo Ltda - Vistos.Indefiro o pedido, porquantonão esgotados os meios para localização de outros bens da parteexecutada, anotando-se que a execução deve se processarda forma menos gravosa e a penhora do faturamento, além de inviabilizar a empresa executada, onerará o processo, ante anecessidade de nomeação de administrador-depositário, que teráremuneração mensal. Ademais, o ordenamento jurídico prevêordem preferencial de penhora que deve ser observada, conformedisposto no artigo 835 do Código de Processo Civil.Intime-se. - ADV: JOSE CARLOS D’ANDREA (OAB 22615/SP), LUIZ CARLOS AMARO PEDROSA VIEIRA (OAB 246744/SP), LUISCARLOS CIOFFI BALTRAMAVICIUS (OAB 123851/SP)Processo  0028605-54.2017.8.26.0100  (processo  principal  1071666-79.2016.8.26.0100)  -  Cumprimento  de  sentença  -Inclusão Indevida em Cadastro de Inadimplentes - Fábio RogérioAbe Ribeiro - Ciência da juntada do AR negativo. - ADV:NAUJALIS SOCIEDADE INDIVIDUAL DE ADVOCACIA (OAB 19040/SP), CRISTINA NAUJALIS DE OLIVEIRA (OAB 357592/SP)Processo  0030677-14.2017.8.26.0100  (processo  principal  1056022-04.2013.8.26.0100)  -  Cumprimento  de  sentença- Inadimplemento - Banco do Brasil S.A. - SERGIO ASSAD IBRI - Vistos.Primeiramente, manifeste-se o exequente sobre aimpugnação e documentos de fls.32/58. Após, tornem conclusos.Intime-se. - ADV: MARCOS CALDAS MARTINS CHAGAS (OAB303021/SP), BRUNO KURZWEIL DE OLIVEIRA (OAB 248704/SP), 9JOEL LUIS THOMAZ BASTOS (OAB 122443/SP)Processo  0032840-64.2017.8.26.0100  (processo  principal  1128654-91.2014.8.26.0100)  -  Cumprimento  de  sentença-  Indenização  por  Dano  Material  -  VALDEMIR  APARECIDO  DE  CARVALHO  SILVA  e  outro  -  MADRI  INVESTIMENTOSIMOBILIÁRIOS  SPE  LTDA  -  Vistos.Fls.66/67:  Diga  a  executada.Intime-se.  - ADV:  MARLENE  FONSECA  MACHADO  (OAB178912/SP), ELISA JUNQUEIRA FIGUEIREDO TALIBERTI (OAB 148842/SP)Processo  0033887-73.2017.8.26.0100  (processo  principal  1058515-46.2016.8.26.0100)  -  Cumprimento  de  sentença  -Seguro - Porto Seguro Companhia de Seguros Gerais - Vistos.Segundo consta dos autos, o executado não constituiu advogadona presente demanda, razão pela qual necessária se faz sua intimação pessoal nos termos dos artigos 513, §2°, inciso II e523 ambos do Código de Processo Civil. Assim sendo, deixo, porora, de apreciar a petição de fls.11/17 e determino que oexequente providencie os meios necessários para tanto.Intime-se. - ADV: JOSE CARLOS VAN CLEEF DE ALMEIDA SANTOS(OAB 273843/SP)Processo  0047167-14.2017.8.26.0100  (processo  principal  1042408-29.2013.8.26.0100)  -  Cumprimento  de  sentença  -Sociedade - MASSAYOSHI PAULO NISHIMURA - Grupo Essentium S.L.,- Na forma do artigo 513 §2º, intime-se, pela imprensa,o executado para que, no prazo de 15 (quinze) dias, pague o valor indicado no demonstrativo discriminado e atualizado docrédito, acrescido de custas, se houver.Fica a parte executadaadvertida de que, transcorrido o prazo previsto no art. 523 semo pagamento voluntário, inicia-se o prazo de 15 (quinze) dias para que, independentemente de penhora ou nova intimação,apresente, nos próprios autos, sua impugnação.Não ocorrendo pagamento voluntário no prazo do artigo 523 do CPC, o dé ...

# %%
#utilizo regex com o padrao de numero do processo, que foi dado no exercicio, para encontrar todos os numeros de processos.
processos=re.findall('\d{7}-\d{2}.\d{4}.\d{1}.\d{2}.\d{4}',texto)
len(processos)
# Out:
# 18

# %%
processos
# Out:
# ['0001040-18.2017.8.26.0100',
#  '0155113-55.2011.8.26.0100',
#  '0026982-52.2017.8.26.0100',
#  '1021197-29.2016.8.26.0100',
#  '0028605-54.2017.8.26.0100',
#  '1071666-79.2016.8.26.0100',
#  '0030677-14.2017.8.26.0100',
#  '1056022-04.2013.8.26.0100',
#  '0032840-64.2017.8.26.0100',
#  '1128654-91.2014.8.26.0100',
#  '0033887-73.2017.8.26.0100',
#  '1058515-46.2016.8.26.0100',
#  '0047167-14.2017.8.26.0100',
#  '1042408-29.2013.8.26.0100',
#  '0047167-14.2017.8.26.0100',
#  '0047169-81.2017.8.26.0100',
#  '1055991-47.2014.8.26.0100',
#  '0047169-81.2017.8.26.0100']

# %%
#identifica todos os processos unicos do texto
processosUnicos=set(processos)
len(processosUnicos)
# Out:
# 16

# %%
processosUnicos
# Out:
# {'0001040-18.2017.8.26.0100',
#  '0026982-52.2017.8.26.0100',
#  '0028605-54.2017.8.26.0100',
#  '0030677-14.2017.8.26.0100',
#  '0032840-64.2017.8.26.0100',
#  '0033887-73.2017.8.26.0100',
#  '0047167-14.2017.8.26.0100',
#  '0047169-81.2017.8.26.0100',
#  '0155113-55.2011.8.26.0100',
#  '1021197-29.2016.8.26.0100',
#  '1042408-29.2013.8.26.0100',
#  '1055991-47.2014.8.26.0100',
#  '1056022-04.2013.8.26.0100',
#  '1058515-46.2016.8.26.0100',
#  '1071666-79.2016.8.26.0100',
#  '1128654-91.2014.8.26.0100'}
